# %%
# Imports:

import requests
import pandas as pd
import numpy as np
import re
import csv
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import urllib.request
import nltk
import nltk.corpus  
from nltk.text import Text
import sys

from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer
# import usaddress


data_file = 'app/static/data/reviews.csv'

def read_csv(filename):
    with open(filename, 'r') as f:
        data = list(csv.reader(f))
    return data


df = pd.read_csv(data_file, encoding='latin1')

# %% [markdown]
# ### Review Length

# %%
df['review_length'] = df['review'].apply(len)


# Correlation between review length and rating:


df.groupby('rating')['review_length'].hist()

fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111)
df.hist(ax=ax)
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2963: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a228837f0>,
# ...
#       dtype=object)

# %% [markdown]
# #### Matplotlib

# %%
# Print Scatterplot

def showRatingWordScatter(my_dataframe):
    my_dataframe['review_length'] = my_dataframe['review'].apply(len)
    review_length = my_dataframe['rating']
    rating = my_dataframe['review_length']
    plt.scatter(review_length,rating, s=15)
    
    plt.title("Rating-Word Count Scatterplot", fontsize=20)
    plt.xlabel=('Word Count')
    plt.ylabel=("Rating")
    plt.legend(loc='best').get_frame().set_color('chocolate')
    plt.show()
